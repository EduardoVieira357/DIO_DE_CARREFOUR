# %%
import pandas as pd

print('ok!')
# Out:
# ok!

# %%
df = pd.read_csv('ocorrencia_2010_2020.csv', sep=';')
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df.columns
# Out:
# Index(['codigo_ocorrencia', 'codigo_ocorrencia2', 'ocorrencia_classificacao',
#        'ocorrencia_cidade', 'ocorrencia_uf', 'ocorrencia_aerodromo',
#        'ocorrencia_dia', 'ocorrencia_hora', 'total_recomendacoes'],
#       dtype='object')

# %%
df.dtypes
# Out:
# codigo_ocorrencia            int64
# codigo_ocorrencia2           int64
# ocorrencia_classificacao    object
# ocorrencia_cidade           object
# ocorrencia_uf               object
# ocorrencia_aerodromo        object
# ocorrencia_dia              object
# ocorrencia_hora             object
# total_recomendacoes          int64
# dtype: object

# %%
df.ocorrencia_dia  # string ou seja, object
# Out:
# 0       03/01/2010
# 1       03/01/2010
# 2       03/01/2010
# 3       04/01/2010
# 4       05/01/2010
#            ...
# 5747    29/12/2020
# 5748    30/12/2020
# 5749    30/12/2020
# 5750    31/12/2020
# 5751    31/12/2020
# Name: ocorrencia_dia, Length: 5752, dtype: object

# %%
# Convertendo já na leitura do arquivo, informando onde estão as datas
df = pd.read_csv('ocorrencia_2010_2020.csv', sep=';', parse_dates=['ocorrencia_dia'])
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 ****     2010-03-01
# 1               BELÉM            PA                 SBBE     2010-03-01
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-03-01
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-04-01
# 4             PELOTAS            RS                 SBPK     2010-05-01
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# ...

# %%
df.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# dtype: object

# %%
df.ocorrencia_dia  # agora é datetime...
# df.ocorrencia_dia.dt.month
# Out:
# 0      2010-03-01
# 1      2010-03-01
# 2      2010-03-01
# 3      2010-04-01
# 4      2010-05-01
#           ...
# 5747   2020-12-29
# 5748   2020-12-30
# 5749   2020-12-30
# 5750   2020-12-31
# 5751   2020-12-31
# Name: ocorrencia_dia, Length: 5752, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5752 entries, 0 to 5751
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   codigo_ocorrencia         5752 non-null   int64
#  1   codigo_ocorrencia2        5752 non-null   int64
#  2   ocorrencia_classificacao  5752 non-null   object
#  3   ocorrencia_cidade         5752 non-null   object
#  4   ocorrencia_uf             5752 non-null   object
#  5   ocorrencia_aerodromo      5752 non-null   object
#  6   ocorrencia_dia            5752 non-null   datetime64[ns]
#  7   ocorrencia_hora           5751 non-null   object
#  8   total_recomendacoes       5752 non-null   int64
# dtypes: datetime64[ns](1), int64(3), object(5)
# memory usage: 404.6+ KB

# %%
# as datas estão erradas... o certo é dia, mes, ano

# %%
df = pd.read_csv('ocorrencia_2010_2020.csv', sep=';', parse_dates=['ocorrencia_dia'], dayfirst=True)
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# ...

# %%
df.tail()
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 5747           CAMPINAS            SP                 SBKP     2020-12-29
# 5748  LAGOA DA CONFUSÃO            TO                 ****     2020-12-30
# 5749     RIO DE JANEIRO            RJ                 SBGL     2020-12-30
# 5750          VICENTINA            MS                 ****     2020-12-31
# 5751     RIO DE JANEIRO            RJ                 SBJR     2020-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 5747        19:00:00                    0
# ...

# %%
# Nat... dado não existente, do tipo data
# NaN... dado não existente, do tipo object, texto, string
#

# %%
df.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# dtype: object

# %%
df = pd.read_csv('ocorrencia_2010_2020_alterado.csv', sep=';', parse_dates=['ocorrencia_dia'], dayfirst=True)
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 ****     03/50/2010
# 1               BELÉM            PA                 SBBE     03/01/2010
# 2      RIO DE JANEIRO            RJ                 SBRJ     03/01/2010
# 3  LUCAS DO RIO VERDE            MT                 ****     04/01/2010
# 4             PELOTAS            RS                 SBPK     05/01/2010
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# ...

# %%
df.dtypes
# Out:
# codigo_ocorrencia            int64
# codigo_ocorrencia2           int64
# ocorrencia_classificacao    object
# ocorrencia_cidade           object
# ocorrencia_uf               object
# ocorrencia_aerodromo        object
# ocorrencia_dia              object
# ocorrencia_hora             object
# total_recomendacoes          int64
# dtype: object

# %%
# se houver uma data cuja informação é incorreta, tipo mes = 50 (03/50/2010) primeira linha
# o parse-dates não vai funcionar e manterá o tipo como string/object
# ocorrencia_dia = object .... solução abaixo

# %%
import pandas as pd
import pandera as pa
print('ok')
# Out:
# ok

# %%
df = pd.read_csv('ocorrencia_2010_2020.csv', sep=';', parse_dates=['ocorrencia_dia'], dayfirst=True)
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# ...

# %%
schema = pa.DataFrameSchema(
    columns = {
        'coluna_qualquer':pa.Column(pa.Int,required=False),
        'codigo_ocorrencia':pa.Column(pa.Int),
        'codigo_ocorrencia2':pa.Column(pa.Int), 
        'ocorrencia_classificacao':pa.Column(pa.String),
        'ocorrencia_cidade':pa.Column(pa.String), 
        'ocorrencia_uf':pa.Column(pa.String, pa.Check.str_length(2,2)), 
        'ocorrencia_aerodromo':pa.Column(pa.String),
        'ocorrencia_dia':pa.Column(pa.DateTime), 
        'ocorrencia_hora':pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|2[0-3]):[0-5][0-9]:[0-5][0-9]?$'),nullable=True),
        'total_recomendacoes':pa.Column(pa.Int)
        
    }
)

# professor r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9)(:[0-5][0-9])?$'
# eu        r'^([0-1]?[0-9]|2[0-3]):[0-5][0-9]:[0-5][0-9]?$'

# %%
schema.validate(df)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
### alteramos o 'ocorrencia_hora':pa.Column(pa.String,nullable=True), para aceitar
### valores nulos.... na verdade o schema é só para validar... não gostei!
#
# pa.Check.str_matches(r'^([0-1]?[0-9]|2[0-3]):[0-5][0-9]:[0-5][0-9]?$')
# faz uma imposição do formato da string que está na coluna... se não atender a isso, dá erro!
# é a tal expressão regular!
#
# 'coluna_qualquer':pa.Column(pa.Int,required=False),
# vai que as vezes uma coluna vem no arquivo mas não é certo... então usa isso

# %%
df.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5752 entries, 0 to 5751
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   codigo_ocorrencia         5752 non-null   int64
#  1   codigo_ocorrencia2        5752 non-null   int64
#  2   ocorrencia_classificacao  5752 non-null   object
#  3   ocorrencia_cidade         5752 non-null   object
#  4   ocorrencia_uf             5752 non-null   object
#  5   ocorrencia_aerodromo      5752 non-null   object
#  6   ocorrencia_dia            5752 non-null   datetime64[ns]
#  7   ocorrencia_hora           5751 non-null   object
#  8   total_recomendacoes       5752 non-null   int64
# dtypes: datetime64[ns](1), int64(3), object(5)
# memory usage: 404.6+ KB

# %%
# prefiro o info... 7   ocorrencia_hora           5751 non-null   object

# %%
# Vamos resolver agora a hora...
